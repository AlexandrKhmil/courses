# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "stackoverflow" dataset
dataset_ref = client.dataset("stackoverflow", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Construct a reference to the "posts_questions" table
table_ref = dataset_ref.table("users")

# API request - fetch the table
table = client.get_table(table_ref)

# Preview the first five lines of the table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#     id       display_name                                           about_me  \
# 0   22       Matt MacLean  <p>Working backwards to achieve customer outco...
# 1  169       Arnold Zokas                      <p>Developer at OpenTable</p>
# 2  243             Goyuix  <p>I started coding at about age 8 on an Apple...
# 3  317  Joseph Sturtevant                                               None
# 4  346                dwj                                               None
#
#     age                    creation_date                 last_access_date  \
# 0  None 2008-08-01 12:11:11.897000+00:00 2019-06-15 22:06:25.540000+00:00
# 1  None 2008-08-02 22:51:03.507000+00:00 2019-12-19 16:20:12.847000+00:00
# 2  None 2008-08-03 23:49:51.343000+00:00 2020-02-29 17:18:32.680000+00:00
# 3  None 2008-08-04 15:43:28.767000+00:00 2019-12-08 01:36:33.547000+00:00
# 4  None 2008-08-04 21:30:40.220000+00:00 2019-11-22 18:08:52.043000+00:00
#
#                  location  reputation  up_votes  down_votes  views  \
# 0         Calgary, Canada       16064       203           5   1243
# 1  London, United Kingdom        7403      1979          18    666
# 2      Salt Lake City, UT       20609      4717          73    934
# 3           Vancouver, WA       12070       469          10    782
# 4       San Francisco, CA        3275       309           0    386
#
#                                    profile_image_url  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  https://www.gravatar.com/avatar/453b8cd3e07620...
# 4                                               None
#
#                                  website_url
# 0                    https://aws.amazon.com/
# 1                http://www.opentable.co.uk/
# 2  https://plus.google.com/u/0/+GregMcMurray
# 3             http://sturtevant.myopenid.com
# 4                                       None

# %%
query = '''
    select * 
    from `bigquery-public-data.stackoverflow.users` 
    where display_name like '%stay-masya%';
'''
query_job = client.query(query)
query_job.to_dataframe().head()
# Out:
# Empty DataFrame
# Columns: [id, display_name, about_me, age, creation_date, last_access_date, location, reputation, up_votes, down_votes, views, profile_image_url, website_url]
# Index: []
